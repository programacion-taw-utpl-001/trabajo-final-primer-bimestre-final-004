# %%
import pandas as pd

# %%
datos=pd.read_csv('EMA-2016-1.csv', engine='python')
datos
# Out:
#        ofi_insc  prov_insc   cant_insc                      parr_insc  \
# 0             1       Loja  EspÃ­ndola     Amaluza, cabecera cantonal
# 1             1  Pichincha       Quito                     ItchimbÃ­a
# 2             1  Pichincha       Quito                      IÃ±aquito
# 3             1  Pichincha       Quito                     ItchimbÃ­a
# 4             1  Pichincha       Quito                      IÃ±aquito
# 5             1  Pichincha       Quito                        Tumbaco
# 6             1  Pichincha       Quito                      IÃ±aquito
# 7             1  Pichincha       Quito                     ItchimbÃ­a
# 8             1  Pichincha       Quito                      IÃ±aquito
# 9             1  Pichincha       Quito                      IÃ±aquito
# 10            1  Pichincha       Quito                      IÃ±aquito
# 11            1  Pichincha       Quito                      IÃ±aquito
# ...

# %%
datos.columns
# Out:
# Index(['ofi_insc', 'prov_insc', 'cant_insc', 'parr_insc', 'anio_insc',
#        'mes_insc', 'dia_insc', 'fecha_insc', 'hijos_rec', 'mcap_bie',
#        'nac_hom', 'cod_paish', 'anio_nach', 'mes_nach', 'dia_nach',
#        'fecha_nach', 'edad_hom', 'nmatanth', 'est_civih', 'p_etnica_hom',
#        'sabe_leerh', 'niv_insth', 'prov_habh', 'cant_habh', 'parr_habh',
#        'area_hom', 'nac_muj', 'cod_paism', 'anio_nacm', 'mes_nacm', 'dia_nacm',
#        'fecha_nacm', 'edad_muj', 'nmatantm', 'est_civim', 'p_etnica_muj',
#        'sabe_leerm', 'niv_instm', 'prov_habm', 'cant_habm', 'parr_habm',
#        'area_muj'],
#       dtype='object')

# %%
tabla1 = pd.read_csv('EMA-2016-1.csv')

# %%
type(tabla1)
# Out:
# pandas.core.frame.DataFrame

# %%
tabla1[['ofi_insc','prov_insc', 'cant_insc', 'parr_insc', 'anio_insc', 'mes_insc', 'dia_insc', 'fecha_insc', 'edad_muj', 'est_civim']]
# Out:
#        ofi_insc  prov_insc   cant_insc                      parr_insc  \
# 0             1       Loja   Espíndola     Amaluza, cabecera cantonal
# 1             1  Pichincha       Quito                      Itchimbía
# 2             1  Pichincha       Quito                       Iñaquito
# 3             1  Pichincha       Quito                      Itchimbía
# 4             1  Pichincha       Quito                       Iñaquito
# 5             1  Pichincha       Quito                        Tumbaco
# 6             1  Pichincha       Quito                       Iñaquito
# 7             1  Pichincha       Quito                      Itchimbía
# 8             1  Pichincha       Quito                       Iñaquito
# 9             1  Pichincha       Quito                       Iñaquito
# 10            1  Pichincha       Quito                       Iñaquito
# 11            1  Pichincha       Quito                       Iñaquito
# ...

# %%
tabla2 = tabla1[tabla1['prov_insc'] == 'Loja']
tabla3=tabla2[tabla2['est_civim']== 'Soltera']
tabla4=tabla3[tabla3['niv_instm']=='Primaria']
tabla5=tabla4[tabla4['area_muj']=='Urbana']
tabla5
# Out:
#        ofi_insc prov_insc cant_insc  \
# 1146          1      Loja      Loja
# 1160          1      Loja  Saraguro
# 1265          1      Loja      Loja
# 2957          1      Loja      Loja
# 3213          1      Loja      Loja
# 3225          1      Loja      Loja
# 6028          1      Loja    Celica
# 9085          1      Loja      Loja
# 10527         1      Loja      Loja
# 10796         1      Loja    Celica
# 11053         1      Loja  Saraguro
# 11079         1      Loja    Celica
# 11451         1      Loja    Celica
# 16158         1      Loja    Macará
# 16211         1      Loja    Calvas
# 23977         1      Loja  Catamayo
# 29380         1      Loja      Loja
# 30426         1      Loja      Loja
# 30495         1      Loja    Macará
# 30518         1      Loja      Loja
# 30538         1      Loja    Celica
# 30539         1      Loja  Catamayo
# 30570         1      Loja      Loja
# 30587         1      Loja    Paltas
# 30593         1      Loja  Catamayo
# ...

# %%
from bokeh.io import show
from bokeh.plotting import figure

# %%
from bokeh.io import output_notebook, output_file
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c9a27c1a-0a1b-4332-935b-9083793f644b">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("mujeres de loja.html")

fruits = ['20-25', '25-30', '30-35', '35-40', '40-80']
counts = [14, 14, 6, 5, 22, ]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="intervalo de mujeres solteras de loja")
p.vbar(x='fruits', top='counts', width=0.9, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d22f9592-e295-4d01-86b0-ba569f8abfd1"></div>
# </div>

# %%
tabla2 = tabla1[tabla1['prov_insc'] == 'Loja']
tabla3=tabla2[tabla2['est_civim']== 'Soltera']
tabla4=tabla3[tabla3['area_muj']=='Urbana']
tabla4
# Out:
#        ofi_insc prov_insc  cant_insc  \
# 727           1      Loja       Loja
# 1146          1      Loja       Loja
# 1160          1      Loja   Saraguro
# 1265          1      Loja       Loja
# 1410          1      Loja       Loja
# 1591          1      Loja       Loja
# 1796          1      Loja       Loja
# 2514          1      Loja       Loja
# 2957          1      Loja       Loja
# 3189          1      Loja       Loja
# 3202          1      Loja       Loja
# 3219          1      Loja       Loja
# 3225          1      Loja       Loja
# 4352          1      Loja     Macará
# 4395          1      Loja       Loja
# 4427          1      Loja     Celica
# 6028          1      Loja     Celica
# 7036          1      Loja       Loja
# 9085          1      Loja       Loja
# 10375         1      Loja     Paltas
# 10474         1      Loja       Loja
# 10477         1      Loja       Loja
# 10498         1      Loja       Loja
# 10527         1      Loja       Loja
# ...

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Sperior', 'Primaria', 'secundaria', 'PstBachillerato', 'Educacion Media']
counts = [14, 12, 20, 2, 7]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="Intervalo de nivel de educacion Mujeres")
p.vbar(x='fruits', top='counts', width=0.9, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6c8c42d3-7a3b-4802-8da5-9c218364aa7f"></div>
# </div>

# %%
tabla2 = tabla1[tabla1['prov_insc'] == 'Loja']
tabla3=tabla2[tabla2['est_civim']== 'Soltera']
tabla3
# Out:
#        ofi_insc prov_insc  cant_insc  \
# 727           1      Loja       Loja
# 1146          1      Loja       Loja
# 1160          1      Loja   Saraguro
# 1265          1      Loja       Loja
# 1395          1      Loja   Saraguro
# 1410          1      Loja       Loja
# 1446          1      Loja   Catamayo
# 1591          1      Loja       Loja
# 1796          1      Loja       Loja
# 1819          1      Loja   Saraguro
# 2351          1      Loja  Zapotillo
# 2514          1      Loja       Loja
# 2954          1      Loja       Loja
# 2957          1      Loja       Loja
# 3189          1      Loja       Loja
# 3202          1      Loja       Loja
# 3219          1      Loja       Loja
# 3225          1      Loja       Loja
# 4352          1      Loja     Macará
# 4395          1      Loja       Loja
# 4427          1      Loja     Celica
# 4645          1      Loja     Celica
# 6028          1      Loja     Celica
# 7036          1      Loja       Loja
# ...

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_file

factors = ["Urbano","Rural"]
x =  [50, 9]

dot = figure(title="Intervalo de sectores de mujeres solteras", tools="", toolbar_location=None,
            y_range=factors, x_range=[0,100])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )





show(row(hm, dot, sizing_mode="scale_width"))  # open a browser
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0357383b-5d73-4a82-9033-6e04f481bafc"></div>
# </div>

# %%
tabla2 = tabla1[tabla1['prov_insc'] == 'Loja']
tabla3=tabla2[tabla2['est_civim']== 'Viuda']
tabla3
# Out:
#        ofi_insc prov_insc  cant_insc  \
# 207           1      Loja       Loja
# 10282         1      Loja   Catamayo
# 30429         1      Loja   Catamayo
# 30441         1      Loja   Saraguro
# 30444         1      Loja     Macará
# 30446         1      Loja       Loja
# 30450         1      Loja   Saraguro
# 30452         1      Loja       Loja
# 30468         1      Loja       Loja
# 30475         1      Loja       Loja
# 30479         1      Loja       Loja
# 30509         1      Loja   Catamayo
# 30546         1      Loja       Loja
# 30549         1      Loja     Macará
# 30565         1      Loja   Catamayo
# 30568         1      Loja   Catamayo
# 30587         1      Loja     Paltas
# 30591         1      Loja       Loja
# 30658         1      Loja       Loja
# 30778         1      Loja       Loja
# 30825         1      Loja  Espíndola
# 30944         1      Loja   Catamayo
# 31113         1      Loja   Catamayo
# 31190         1      Loja       Loja
# ...

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Urbano', 'Rural']
counts = [25, 2]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="Intervalo de nivel de viudas en sectores")
p.vbar(x='fruits', top='counts', width=0.9, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8e5ae699-a248-4750-9cc4-f6884571e161"></div>
# </div>

# %%
tabla2 = tabla1[tabla1['prov_insc'] == 'Loja']
tabla3=tabla2[tabla2['cant_habm']== 'Loja']
tabla4=tabla3[tabla3['niv_instm']=='Secundaria']
tabla4
# Out:
#        ofi_insc prov_insc cant_insc  \
# 1591          1      Loja      Loja
# 3189          1      Loja      Loja
# 3202          1      Loja      Loja
# 10336         1      Loja      Loja
# 10498         1      Loja      Loja
# 11041         1      Loja      Loja
# 11402         1      Loja      Loja
# 11440         1      Loja      Loja
# 11642         1      Loja      Loja
# 11710         1      Loja      Loja
# 11711         1      Loja      Loja
# 11804         1      Loja      Loja
# 12361         1      Loja      Loja
# 12566         1      Loja      Loja
# 12571         1      Loja      Loja
# 14729         1      Loja      Loja
# 16030         1      Loja      Loja
# 18694         1      Loja      Loja
# 23193         1      Loja      Loja
# 28115         1      Loja      Loja
# 30449         1      Loja      Loja
# 30451         1      Loja      Loja
# 30452         1      Loja      Loja
# 30461         1      Loja      Loja
# 30463         1      Loja      Loja
# ...

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

output_file("bar_colormapped.html")

fruits = ['Soltera', 'Viuda', 'Divorsiada']
counts = [46, 11, 2]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="Intervalo de estado civil de mujeres del canton Loja")
p.vbar(x='fruits', top='counts', width=0.9, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="610f42d2-4482-4b8f-a8e6-7af5494aa1c4"></div>
# </div>
